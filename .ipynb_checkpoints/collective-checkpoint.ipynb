# %%
import sys
assert sys.version_info>=(3,5)

import sklearn 
assert sklearn.__version__>="0.20"

import numpy as np
import pandas as pd
import os

import matplotlib as mpl
# %matplotlib inline

import matplotlib.pyplot as plt

mpl.rc('axes',labelsize=14)
mpl.rc('xtick',labelsize=12)
mpl.rc('ytick',labelsize=12)

PROJECT_DIR="."
CHAPTER_ID = "Animal Disease detection"
IMAGE_PATH = os.path.join(PROJECT_DIR,"figures",CHAPTER_ID)
os.makedirs(IMAGE_PATH,exist_ok = True)

def save_fig(fig_id,tight_layout = True , fig_extension = True , resolution= 300):
    path=os.path.join(IMAGE_PATH,fig_id+"."+fig_extension)
    print("saving fig",fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %%
# fetching data from system
data_path=r"C:\Users\yashh\datasets\animal_disease_dataset.csv"
def load_data(path=data_path):
    return pd.read_csv(path)

# %%
disease = load_data()
disease.head()
# Out:
#     Animal  Age  Temperature         Symptom 1         Symptom 2  \
# 0      cow    3        103.1        depression    painless lumps
# 1  buffalo   13        104.5    painless lumps  loss of appetite
# 2    sheep    1        100.5        depression    painless lumps
# 3      cow   14        100.3  loss of appetite  swelling in limb
# 4    sheep    2        103.6    painless lumps  loss of appetite
#
#           Symptom 3      Disease
# 0  loss of appetite    pneumonia
# 1        depression  lumpy virus
# 2  loss of appetite  lumpy virus
# 3   crackling sound     blackleg
# 4        depression    pneumonia

# %%
disease.describe()
# Out:
#                 Age   Temperature
# count  43778.000000  43778.000000
# mean       6.769131    102.269590
# std        3.886739      1.400872
# min        1.000000    100.000000
# 25%        4.000000    101.100000
# 50%        7.000000    102.200000
# 75%       10.000000    103.400000
# max       15.000000    105.000000

# %%
disease.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43778 entries, 0 to 43777
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Animal       43778 non-null  object
#  1   Age          43778 non-null  int64
#  2   Temperature  43778 non-null  float64
#  3   Symptom 1    43778 non-null  object
#  4   Symptom 2    43778 non-null  object
#  5   Symptom 3    43778 non-null  object
#  6   Disease      43778 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 2.3+ MB

# %%
disease['Symptom 1'].value_counts()
# Out:
# Symptom 1
# loss of appetite           10026
# depression                  6770
# painless lumps              4815
# difficulty walking          2594
# lameness                    2578
# crackling sound             1991
# shortness of breath         1698
# fatigue                     1678
# chest discomfort            1659
# sweats                      1604
# chills                      1597
# swelling in muscle           972
# swelling in limb             933
# swelling in extremities      538
# swelling in neck             535
# swelling in abdomen          533
# blisters on tongue           436
# blisters on hooves           427
# sores on tongue              414
# sores on gums                412
# blisters on mouth            410
# sores on mouth               403
# blisters on gums             396
# sores on hooves              359
# Name: count, dtype: int64

# %%
disease['Symptom 2'].value_counts()
# Out:
# Symptom 2
# loss of appetite           10068
# depression                  6755
# painless lumps              4849
# difficulty walking          2608
# lameness                    2564
# crackling sound             1921
# chills                      1659
# sweats                      1643
# shortness of breath         1640
# chest discomfort            1639
# fatigue                     1610
# swelling in muscle          1008
# swelling in limb             913
# swelling in abdomen          569
# swelling in extremities      549
# swelling in neck             533
# sores on tongue              441
# sores on hooves              436
# blisters on gums             405
# blisters on hooves           405
# sores on gums                401
# blisters on tongue           398
# sores on mouth               387
# blisters on mouth            377
# Name: count, dtype: int64

# %%
disease['Symptom 3'].value_counts()
# Out:
# Symptom 3
# loss of appetite           10004
# depression                  6809
# painless lumps              4858
# difficulty walking          2603
# lameness                    2536
# crackling sound             1974
# fatigue                     1694
# sweats                      1679
# shortness of breath         1639
# chest discomfort            1626
# chills                      1590
# swelling in muscle          1005
# swelling in limb             953
# swelling in abdomen          578
# swelling in extremities      537
# swelling in neck             499
# sores on gums                439
# sores on mouth               431
# sores on hooves              411
# sores on tongue              403
# blisters on hooves           395
# blisters on mouth            383
# blisters on gums             375
# blisters on tongue           357
# Name: count, dtype: int64

# %%
disease['Disease'].value_counts()
# Out:
# Disease
# anthrax           9842
# blackleg          9713
# foot and mouth    9701
# pneumonia         7330
# lumpy virus       7192
# Name: count, dtype: int64

# %%
disease.hist(bins=50,figsize=(20,15))
# Out:
# array([[<Axes: title={'center': 'Age'}>,
#         <Axes: title={'center': 'Temperature'}>]], dtype=object)

# %%
disease['Disease'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Disease'>

# %%
# import seaborn as sns

# plt.figure(figsize=(10, 8))
# sns.heatmap(disease.corr(), annot=True, cmap='coolwarm', fmt='.2f')
# pl

# %pip install dython
# Out:
# Requirement already satisfied: dython in c:\users\yashh\appdata\local\programs\python\python313\lib\site-packages (0.7.9)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\yashh\appdata\local\programs\python\python313\lib\site-packages (from dython) (2.3.1)
# Requirement already satisfied: pandas>=1.4.2 in c:\users\yashh\appdata\local\programs\python\python313\lib\site-packages (from dython) (2.3.0)
# Requirement already satisfied: seaborn>=0.12.0 in c:\users\yashh\appdata\local\programs\python\python313\lib\site-packages (from dython) (0.13.2)
# Requirement already satisfied: scipy>=1.7.1 in c:\users\yashh\appdata\local\programs\python\python313\lib\site-packages (from dython) (1.16.0)
# Requirement already satisfied: matplotlib>=3.6.0 in c:\users\yashh\appdata\local\programs\python\python313\lib\site-packages (from dython) (3.10.3)
# Requirement already satisfied: scikit-learn>=0.24.2 in c:\users\yashh\appdata\local\programs\python\python313\lib\site-packages (from dython) (1.7.0)
# Requirement already satisfied: psutil>=5.9.1 in c:\users\yashh\appdata\local\programs\python\python313\lib\site-packages (from dython) (7.0.0)
# Requirement already satisfied: setuptools in c:\users\yashh\appdata\local\programs\python\python313\lib\site-packages (from dython) (80.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\yashh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.6.0->dython) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\yashh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.6.0->dython) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yashh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.6.0->dython) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\yashh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.6.0->dython) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\yashh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.6.0->dython) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\yashh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.6.0->dython) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\yashh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.6.0->dython) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yashh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.6.0->dython) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yashh\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.4.2->dython) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\yashh\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.4.2->dython) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\yashh\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->dython) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\yashh\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn>=0.24.2->dython) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\yashh\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn>=0.24.2->dython) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from dython.nominal import theils_u

theils_u(disease['Animal'],disease['Disease'])
# Out:
# np.float64(0.000370717920562659)

# %%
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency

def cramers_v(x, y):
    confusion_matrix = pd.crosstab(x, y)
    chi2 = chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2 / n
    r, k = confusion_matrix.shape
    phi2corr = max(0, phi2 - ((k-1)*(r-1))/(n-1))
    rcorr = r - ((r-1)**2)/(n-1)
    kcorr = k - ((k-1)**2)/(n-1)
    return np.sqrt(phi2corr / min((kcorr-1), (rcorr-1)))

# Example:
cramers_v(disease['Animal'], disease['Disease'])
# cramers v is like correlation coefficient but for categorial data.
# Out:
# np.float64(0.01584430252104881)

# %%
from scipy.stats import chi2_contingency

contingency_table = pd.crosstab(disease['Animal'], disease['Disease'])
chi2, p, dof, expected = chi2_contingency(contingency_table)

print(f"Chi2 Statistic: {chi2}")
print(f"p-value: {p}")
# p value tells us if the null hypo is true or not and the null hypo is two variables being
# independent and lower the  p value higher the dependance.
# and chi 2 test tells if the two variables are related strongly or not
# Out:
# Chi2 Statistic: 44.96835452129246
# p-value: 1.0434445324745116e-05

# %%
cat_cols = ['Animal', 'Symptom 1', 'Symptom 2', 'Symptom 3', 'Disease']

# -------------------------
# 🟦 Cramér’s V Heatmap
# -------------------------
def cramers_v(x, y):
    confusion_matrix = pd.crosstab(x, y)
    chi2 = chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    r, k = confusion_matrix.shape
    return np.sqrt(chi2 / (n * (min(k - 1, r - 1))))

cramer_matrix = pd.DataFrame(index=cat_cols, columns=cat_cols)

for col1 in cat_cols:
    for col2 in cat_cols:
        cramer_matrix.loc[col1, col2] = cramers_v(disease[col1],disease[col2])

cramer_matrix = cramer_matrix.astype(float)

plt.figure(figsize=(10, 7))
sns.heatmap(cramer_matrix, annot=True, cmap='coolwarm')
plt.title("Cramér's V Heatmap")
plt.show()

# -------------------------
# 🟨 Theil’s U Heatmap
# -------------------------
theil_matrix = pd.DataFrame(index=cat_cols, columns=cat_cols)

for col1 in cat_cols:
    for col2 in cat_cols:
        theil_matrix.loc[col1, col2] = theils_u(disease[col1], disease[col2])

theil_matrix = theil_matrix.astype(float)

plt.figure(figsize=(10, 7))
sns.heatmap(theil_matrix, annot=True, cmap='viridis')
plt.title("Theil's U Heatmap (Predictive Power)")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# count of each disease per animal
plt.figure(figsize=(12,6))
sns.countplot(data= disease,x='Animal',hue='Disease')
plt.title('Disease Frequency per Animal')
plt.xticks(rotation=45) #changes the alignment of the name of the categorie
plt.legend(loc='upper right')
plt.tight_layout()
plt.show()

# %%
disease.head()
# Out:
#     Animal  Age  Temperature         Symptom 1         Symptom 2  \
# 0      cow    3        103.1        depression    painless lumps
# 1  buffalo   13        104.5    painless lumps  loss of appetite
# 2    sheep    1        100.5        depression    painless lumps
# 3      cow   14        100.3  loss of appetite  swelling in limb
# 4    sheep    2        103.6    painless lumps  loss of appetite
#
#           Symptom 3      Disease
# 0  loss of appetite    pneumonia
# 1        depression  lumpy virus
# 2  loss of appetite  lumpy virus
# 3   crackling sound     blackleg
# 4        depression    pneumonia

# %%
for col in['Animal','Symptom 1','Symptom 2','Symptom 3']:
    plt.figure(figsize=(8,4))
    sns.countplot(data = disease , x = col , order = disease[col].value_counts().index)
    plt.xticks(rotation=45)
    plt.title(f"distribution of {col}")
    plt.show()

# %%
sns.boxplot(data=disease, x='Disease', y='Temperature')
plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns
sns.pairplot(disease, hue='Disease')
plt.show()

# %%
# checking common symptoms in animals
disease.groupby('Animal')['Symptom 1'].value_counts()
# Out:
# Animal   Symptom 1
# buffalo  loss of appetite      2585
#          depression            1721
#          painless lumps        1306
#          lameness               683
#          difficulty walking     632
#                                ...
# sheep    sores on gums           98
#          sores on mouth          95
#          blisters on gums        90
#          blisters on hooves      89
#          sores on hooves         75
# Name: count, Length: 96, dtype: int64

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split= StratifiedShuffleSplit(n_splits =1, test_size =0.2, random_state = 42)
for train_index, test_index in split.split(disease,disease['Disease']):
    strat_train_set=disease.loc[train_index]
    strat_test_set = disease.loc[test_index]

strat_train_set.head()
# Out:
#         Animal  Age  Temperature         Symptom 1         Symptom 2  \
# 1088     sheep    1        104.4        depression    painless lumps
# 25790  buffalo   11        100.9            sweats            chills
# 23550    sheep    7        102.0        depression  loss of appetite
# 24445  buffalo    3        100.9  loss of appetite        depression
# 37314  buffalo    2        103.5  loss of appetite          lameness
#
#                 Symptom 3         Disease
# 1088     loss of appetite     lumpy virus
# 25790             fatigue         anthrax
# 23550  swelling in muscle        blackleg
# 24445     crackling sound        blackleg
# 37314     sores on tongue  foot and mouth

# %%
disease_copy= disease.copy()
disease = strat_train_set.copy()

# %%
disease = strat_train_set.drop("Disease",axis=1)
disease_labels = strat_train_set['Disease'].copy()
disease.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35022 entries, 1088 to 36169
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Animal       35022 non-null  object
#  1   Age          35022 non-null  int64
#  2   Temperature  35022 non-null  float64
#  3   Symptom 1    35022 non-null  object
#  4   Symptom 2    35022 non-null  object
#  5   Symptom 3    35022 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.9+ MB

# %%
disease_labels
# Out:
# 1088        lumpy virus
# 25790           anthrax
# 23550          blackleg
# 24445          blackleg
# 37314    foot and mouth
#               ...
# 6701        lumpy virus
# 16941           anthrax
# 42500       lumpy virus
# 15711       lumpy virus
# 36169          blackleg
# Name: Disease, Length: 35022, dtype: object

# %%
disease.head()
# Out:
#         Animal  Age  Temperature         Symptom 1         Symptom 2  \
# 1088     sheep    1        104.4        depression    painless lumps
# 25790  buffalo   11        100.9            sweats            chills
# 23550    sheep    7        102.0        depression  loss of appetite
# 24445  buffalo    3        100.9  loss of appetite        depression
# 37314  buffalo    2        103.5  loss of appetite          lameness
#
#                 Symptom 3
# 1088     loss of appetite
# 25790             fatigue
# 23550  swelling in muscle
# 24445     crackling sound
# 37314     sores on tongue

# %%
diseaseexp = disease_copy.copy()

# %%
diseaseexp['Temp_level']=pd.cut(diseaseexp['Temperature'],bins=[0,98,102,106,110],labels=['low','normal','fever','hyper'])

# %%
diseaseexp
# Out:
#         Animal  Age  Temperature                Symptom 1         Symptom 2  \
# 0          cow    3        103.1               depression    painless lumps
# 1      buffalo   13        104.5           painless lumps  loss of appetite
# 2        sheep    1        100.5               depression    painless lumps
# 3          cow   14        100.3         loss of appetite  swelling in limb
# 4        sheep    2        103.6           painless lumps  loss of appetite
# ...        ...  ...          ...                      ...               ...
# 43773     goat    9        102.2       swelling in muscle          lameness
# 43774  buffalo    3        101.8         loss of appetite    sores on mouth
# 43775  buffalo   15        104.1  swelling in extremities            chills
# 43776      cow    9        104.9          crackling sound          lameness
# 43777  buffalo    4        103.5       difficulty walking     sores on gums
#
#                  Symptom 3         Disease Temp_level
# 0         loss of appetite       pneumonia      fever
# 1               depression     lumpy virus      fever
# 2         loss of appetite     lumpy virus     normal
# 3          crackling sound        blackleg     normal
# 4               depression       pneumonia      fever
# ...                    ...             ...        ...
# 43773      crackling sound        blackleg      fever
# 43774   difficulty walking  foot and mouth     normal
# 43775  shortness of breath         anthrax      fever
# 43776   swelling in muscle        blackleg      fever
# 43777     loss of appetite  foot and mouth      fever
#
# [43778 rows x 8 columns]

# %%
diseaseexp=diseaseexp.drop('Temperature',axis=1)

# %%
diseaseexp
# Out:
#         Animal  Age                Symptom 1         Symptom 2  \
# 0          cow    3               depression    painless lumps
# 1      buffalo   13           painless lumps  loss of appetite
# 2        sheep    1               depression    painless lumps
# 3          cow   14         loss of appetite  swelling in limb
# 4        sheep    2           painless lumps  loss of appetite
# ...        ...  ...                      ...               ...
# 43773     goat    9       swelling in muscle          lameness
# 43774  buffalo    3         loss of appetite    sores on mouth
# 43775  buffalo   15  swelling in extremities            chills
# 43776      cow    9          crackling sound          lameness
# 43777  buffalo    4       difficulty walking     sores on gums
#
#                  Symptom 3         Disease Temp_level
# 0         loss of appetite       pneumonia      fever
# 1               depression     lumpy virus      fever
# 2         loss of appetite     lumpy virus     normal
# 3          crackling sound        blackleg     normal
# 4               depression       pneumonia      fever
# ...                    ...             ...        ...
# 43773      crackling sound        blackleg      fever
# 43774   difficulty walking  foot and mouth     normal
# 43775  shortness of breath         anthrax      fever
# 43776   swelling in muscle        blackleg      fever
# 43777     loss of appetite  foot and mouth      fever
#
# [43778 rows x 7 columns]

# %%
theils_u(diseaseexp['Temp_level'],diseaseexp['Disease'])
# Out:
# np.float64(0.00021357627053845458)

# %%
disease
# Out:
#         Animal  Age  Temperature           Symptom 1         Symptom 2  \
# 1088     sheep    1        104.4          depression    painless lumps
# 25790  buffalo   11        100.9              sweats            chills
# 23550    sheep    7        102.0          depression  loss of appetite
# 24445  buffalo    3        100.9    loss of appetite        depression
# 37314  buffalo    2        103.5    loss of appetite          lameness
# ...        ...  ...          ...                 ...               ...
# 6701   buffalo   12        104.6      painless lumps        depression
# 16941      cow    5        101.3              chills  swelling in neck
# 42500      cow   15        104.1      painless lumps  loss of appetite
# 15711      cow   13        102.6          depression  loss of appetite
# 36169     goat    1        104.1  swelling in muscle  loss of appetite
#
#                 Symptom 3
# 1088     loss of appetite
# 25790             fatigue
# 23550  swelling in muscle
# 24445     crackling sound
# 37314     sores on tongue
# ...                   ...
# 6701     loss of appetite
# 16941              sweats
# 42500          depression
# 15711      painless lumps
# 36169            lameness
#
# [35022 rows x 6 columns]

# %%
# from sklearn.compose import ColumnTransformer

# preprocessing = make(
#     SimpleImputer
# )

# %%
disease1 =disease_copy.copy()

# %%
disease1
# Out:
#         Animal  Age  Temperature                Symptom 1         Symptom 2  \
# 0          cow    3        103.1               depression    painless lumps
# 1      buffalo   13        104.5           painless lumps  loss of appetite
# 2        sheep    1        100.5               depression    painless lumps
# 3          cow   14        100.3         loss of appetite  swelling in limb
# 4        sheep    2        103.6           painless lumps  loss of appetite
# ...        ...  ...          ...                      ...               ...
# 43773     goat    9        102.2       swelling in muscle          lameness
# 43774  buffalo    3        101.8         loss of appetite    sores on mouth
# 43775  buffalo   15        104.1  swelling in extremities            chills
# 43776      cow    9        104.9          crackling sound          lameness
# 43777  buffalo    4        103.5       difficulty walking     sores on gums
#
#                  Symptom 3         Disease
# 0         loss of appetite       pneumonia
# 1               depression     lumpy virus
# 2         loss of appetite     lumpy virus
# 3          crackling sound        blackleg
# 4               depression       pneumonia
# ...                    ...             ...
# 43773      crackling sound        blackleg
# 43774   difficulty walking  foot and mouth
# 43775  shortness of breath         anthrax
# 43776   swelling in muscle        blackleg
# 43777     loss of appetite  foot and mouth
#
# [43778 rows x 7 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le_animal=LabelEncoder()
disease1['animal_encoded']=le_animal.fit_transform(disease1['Animal'])

# %% [raw]
# disease1

# %%
disease1
# Out:
#         Animal  Age  Temperature                Symptom 1         Symptom 2  \
# 0          cow    3        103.1               depression    painless lumps
# 1      buffalo   13        104.5           painless lumps  loss of appetite
# 2        sheep    1        100.5               depression    painless lumps
# 3          cow   14        100.3         loss of appetite  swelling in limb
# 4        sheep    2        103.6           painless lumps  loss of appetite
# ...        ...  ...          ...                      ...               ...
# 43773     goat    9        102.2       swelling in muscle          lameness
# 43774  buffalo    3        101.8         loss of appetite    sores on mouth
# 43775  buffalo   15        104.1  swelling in extremities            chills
# 43776      cow    9        104.9          crackling sound          lameness
# 43777  buffalo    4        103.5       difficulty walking     sores on gums
#
#                  Symptom 3         Disease  animal_encoded
# 0         loss of appetite       pneumonia               1
# 1               depression     lumpy virus               0
# 2         loss of appetite     lumpy virus               3
# 3          crackling sound        blackleg               1
# 4               depression       pneumonia               3
# ...                    ...             ...             ...
# 43773      crackling sound        blackleg               2
# 43774   difficulty walking  foot and mouth               0
# 43775  shortness of breath         anthrax               0
# 43776   swelling in muscle        blackleg               1
# 43777     loss of appetite  foot and mouth               0
#
# [43778 rows x 8 columns]

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(drop='first')  # drop='first' mimics drop_first=True
symptom_encoded = encoder.fit_transform(disease1[['Symptom 1']])

# Convert to DataFrame if needed
import pandas as pd
encoded_df = pd.DataFrame(symptom_encoded, columns=encoder.get_feature_names_out(['Symptom 1']))

# Concatenate with original DataFrame (drop original column if needed)
disease1 = disease1.drop('Symptom 1', axis=1)
disease1 = pd.concat([disease1.reset_index(drop=True), encoded_df], axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[191], line 8
#       6 # Convert to DataFrame if needed
#       7 import pandas as pd
# ----> 8 encoded_df = pd.DataFrame(symptom_encoded, columns=encoder.get_feature_names_out(['Symptom 1']))
#      10 # Concatenate with original DataFrame (drop original column if needed)
#      11 disease1 = disease1.drop('Symptom 1', axis=1)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:867, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     859         mgr = arrays_to_mgr(
#     860             arrays,
#     861             columns,
#    (...)    864             typ=manager,
#     865         )
#     866     else:
# --> 867         mgr = ndarray_to_mgr(
#     868             data,
#     869             index,
#     870             columns,
#     871             dtype=dtype,
#     872             copy=copy,
#     873             typ=manager,
#     874         )
#     875 else:
#     876     mgr = dict_to_mgr(
#     877         {},
#     878         index,
#    (...)    881         typ=manager,
#     882     )
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\construction.py:336, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     331 # _prep_ndarraylike ensures that values.ndim == 2 at this point
#     332 index, columns = _get_axes(
#     333     values.shape[0], values.shape[1], index=index, columns=columns
#     334 )
# --> 336 _check_values_indices_shape_match(values, index, columns)
#     338 if typ == "array":
#     339     if issubclass(values.dtype.type, str):
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\construction.py:420, in _check_values_indices_shape_match(values, index, columns)
#     418 passed = values.shape
#     419 implied = (len(index), len(columns))
# --> 420 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (43778, 1), indices imply (43778, 23)

# %%
disease1
# Out:
#         Animal  Age  Temperature                Symptom 1         Symptom 2  \
# 0          cow    3        103.1               depression    painless lumps
# 1      buffalo   13        104.5           painless lumps  loss of appetite
# 2        sheep    1        100.5               depression    painless lumps
# 3          cow   14        100.3         loss of appetite  swelling in limb
# 4        sheep    2        103.6           painless lumps  loss of appetite
# ...        ...  ...          ...                      ...               ...
# 43773     goat    9        102.2       swelling in muscle          lameness
# 43774  buffalo    3        101.8         loss of appetite    sores on mouth
# 43775  buffalo   15        104.1  swelling in extremities            chills
# 43776      cow    9        104.9          crackling sound          lameness
# 43777  buffalo    4        103.5       difficulty walking     sores on gums
#
#                  Symptom 3         Disease  animal_encoded
# 0         loss of appetite       pneumonia               1
# 1               depression     lumpy virus               0
# 2         loss of appetite     lumpy virus               3
# 3          crackling sound        blackleg               1
# 4               depression       pneumonia               3
# ...                    ...             ...             ...
# 43773      crackling sound        blackleg               2
# 43774   difficulty walking  foot and mouth               0
# 43775  shortness of breath         anthrax               0
# 43776   swelling in muscle        blackleg               1
# 43777     loss of appetite  foot and mouth               0
#
# [43778 rows x 8 columns]
